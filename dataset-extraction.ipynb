# %%
import pandas as pd

# %%
annotations_json = pd.read_json('./dataset/MFTC_V4.json')

# %%
annotations_json
# Out:
#       Corpus                                             Tweets
# 0        ALM  [{'tweet_id': '521033092132503552', 'annotatio...
# 1  Baltimore  [{'tweet_id': '593899776564944897', 'annotatio...
# 2        BLM  [{'tweet_id': '734202176684298240', 'annotatio...
# 3   Davidson  [{'tweet_id': '5', 'annotations': [{'annotator...
# 4   Election  [{'tweet_id': '509464992404357120', 'annotatio...
# 5      MeToo  [{'tweet_id': '48430014437122048', 'annotation...
# 6      Sandy  [{'tweet_id': '258018822945120256', 'annotatio...

# %%
annotations_json['Tweets'][0]
# Out:
# [{'tweet_id': '521033092132503552',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care'},
#    {'annotator': 'annotator01', 'annotation': 'care,purity'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '537681598989475841',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'subversion'},
#    {'annotator': 'annotator01', 'annotation': 'subversion'},
#    {'annotator': 'annotator02', 'annotation': 'loyalty'},
#    {'annotator': 'annotator03', 'annotation': 'loyalty,subversion'}]},
#  {'tweet_id': '624644420705648640',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'cheating'},
#    {'annotator': 'annotator03', 'annotation': 'care,cheating'}]},
#  {'tweet_id': '752979765984890884',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care'},
#    {'annotator': 'annotator01', 'annotation': 'purity'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '548029362348765185',
#   'annotations': [{'annotator': 'annotator00',
#     'annotation': 'fairness,cheating'},
#    {'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,loyalty,purity'},
#    {'annotator': 'annotator03', 'annotation': 'cheating'}]},
#  {'tweet_id': '753261224737898497',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care'},
#    {'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '751971806265810944',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'harm'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '676436368268984320',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'non-moral'},
#    {'annotator': 'annotator01', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'non-moral'}]},
#  {'tweet_id': '636902749657919489',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'fairness'},
#    {'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '568112472542064640',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care,harm'},
#    {'annotator': 'annotator01', 'annotation': 'harm'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '540400187458351105',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'non-moral'},
#    {'annotator': 'annotator01', 'annotation': 'cheating'},
#    {'annotator': 'annotator02', 'annotation': 'cheating'},
#    {'annotator': 'annotator03', 'annotation': 'non-moral'}]},
#  {'tweet_id': '751417943427149824',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care'},
#    {'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '546194676441546752',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator01', 'annotation': 'betrayal'},
#    {'annotator': 'annotator02', 'annotation': 'cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '652553203351990272',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care'},
#    {'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '756669445775384576',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care'},
#    {'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care,authority'}]},
#  {'tweet_id': '751585618094940160',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care'},
#    {'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '754861900282814464',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'cheating'},
#    {'annotator': 'annotator01', 'annotation': 'betrayal'},
#    {'annotator': 'annotator02', 'annotation': 'betrayal,degradation'},
#    {'annotator': 'annotator03', 'annotation': 'cheating'}]},
#  {'tweet_id': '553104279666696192',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care,harm'},
#    {'annotator': 'annotator01', 'annotation': 'care,loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '543905079133495296',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'cheating'},
#    {'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'cheating'},
#    {'annotator': 'annotator03', 'annotation': 'cheating'}]},
#  {'tweet_id': '701740341506871297',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator01', 'annotation': 'purity'},
#    {'annotator': 'annotator02', 'annotation': 'cheating'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating,authority'}]},
#  {'tweet_id': '630786843974467584',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator01', 'annotation': 'betrayal'},
#    {'annotator': 'annotator02', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '704336834793353216',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'betrayal'},
#    {'annotator': 'annotator02', 'annotation': 'fairness,cheating'},
#    {'annotator': 'annotator03', 'annotation': 'loyalty'}]},
#  {'tweet_id': '624203733946269696',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'fairness'},
#    {'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'care'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '658042120557559808',
#   'annotations': [{'annotator': 'annotator00',
#     'annotation': 'harm,subversion'},
#    {'annotator': 'annotator01', 'annotation': 'subversion'},
#    {'annotator': 'annotator02', 'annotation': 'harm,cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'harm,subversion'}]},
#  {'tweet_id': '732768520837074949',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'non-moral'},
#    {'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'harm'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '538669623559065601',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'care,authority'}]},
#  {'tweet_id': '755768397883928576',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm'},
#    {'annotator': 'annotator01', 'annotation': 'subversion'},
#    {'annotator': 'annotator02', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator03', 'annotation': 'harm'}]},
#  {'tweet_id': '751557661364105216',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care,loyalty,subversion'}]},
#  {'tweet_id': '505332707002683392',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'care,authority'}]},
#  {'tweet_id': '754732923949985792',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm'},
#    {'annotator': 'annotator01', 'annotation': 'cheating'},
#    {'annotator': 'annotator02', 'annotation': 'harm,fairness,cheating'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '565410689855270912',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm'},
#    {'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'harm,cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'harm'}]},
#  {'tweet_id': '729699680808886274',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator01', 'annotation': 'cheating'},
#    {'annotator': 'annotator02', 'annotation': 'cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'harm,fairness'}]},
#  {'tweet_id': '638460072348135424',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care'},
#    {'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '629949328216444928',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm'},
#    {'annotator': 'annotator01', 'annotation': 'subversion'},
#    {'annotator': 'annotator02', 'annotation': 'cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'harm,fairness,cheating'}]},
#  {'tweet_id': '595418226588266497',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm'},
#    {'annotator': 'annotator01', 'annotation': 'betrayal'},
#    {'annotator': 'annotator02', 'annotation': 'cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'harm,subversion'}]},
#  {'tweet_id': '719549638676615168',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator01', 'annotation': 'subversion'},
#    {'annotator': 'annotator02', 'annotation': 'harm,cheating,degradation'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '639295319218483200',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'authority'},
#    {'annotator': 'annotator01', 'annotation': 'betrayal'},
#    {'annotator': 'annotator02', 'annotation': 'fairness,cheating'},
#    {'annotator': 'annotator03', 'annotation': 'authority'}]},
#  {'tweet_id': '696855546175959040',
#   'annotations': [{'annotator': 'annotator00',
#     'annotation': 'care,fairness,authority'},
#    {'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'harm,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'fairness,loyalty,authority'}]},
#  {'tweet_id': '612423726504759296',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'fairness'},
#    {'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '651774641237790720',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'non-moral'},
#    {'annotator': 'annotator01', 'annotation': 'non-moral'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'loyalty'}]},
#  {'tweet_id': '751334824141434880',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care,harm'},
#    {'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness,purity'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '682318822540447745',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care'},
#    {'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness,loyalty'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '753297544000708608',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'loyalty'},
#    {'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,loyalty'},
#    {'annotator': 'annotator03', 'annotation': 'loyalty,subversion'}]},
#  {'tweet_id': '566387448935374848',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'non-moral'},
#    {'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '547086823043137537',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm'},
#    {'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'degradation'},
#    {'annotator': 'annotator03', 'annotation': 'harm'}]},
#  {'tweet_id': '592818576639336448',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'fairness'},
#    {'annotator': 'annotator01', 'annotation': 'purity'},
#    {'annotator': 'annotator02', 'annotation': 'care'},
#    {'annotator': 'annotator03', 'annotation': 'authority'}]},
#  {'tweet_id': '665629403842498564',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm'},
#    {'annotator': 'annotator01', 'annotation': 'harm'},
#    {'annotator': 'annotator02', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '550847453843320833',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm'},
#    {'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'harm'}]},
#  {'tweet_id': '751495791177441282',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care,harm'},
#    {'annotator': 'annotator01', 'annotation': 'purity'},
#    {'annotator': 'annotator02', 'annotation': 'cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'care,purity'}]},
#  {'tweet_id': '751613963218157569',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care,harm'},
#    {'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care,harm'}]},
#  {'tweet_id': '751317267523244032',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator01', 'annotation': 'cheating'},
#    {'annotator': 'annotator02', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator03', 'annotation': 'harm,fairness,cheating'}]},
#  {'tweet_id': '555686312343109632',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care,harm'},
#    {'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'harm,cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '702864414941298688',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care'},
#    {'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'care,loyalty,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '634376349440942080',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'cheating'},
#    {'annotator': 'annotator01', 'annotation': 'betrayal'},
#    {'annotator': 'annotator02', 'annotation': 'degradation'},
#    {'annotator': 'annotator03', 'annotation': 'cheating'}]},
#  {'tweet_id': '594300751960100865',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care'},
#    {'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '637803934950772736',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm'},
#    {'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'harm,cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'harm'}]},
#  {'tweet_id': '751506828744327168',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '753256121134157824',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm'},
#    {'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'harm'}]},
#  {'tweet_id': '543279093194584065',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator01', 'annotation': 'cheating'},
#    {'annotator': 'annotator02', 'annotation': 'cheating'},
#    {'annotator': 'annotator03', 'annotation': 'harm'}]},
#  {'tweet_id': '593860298114752512',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator01', 'annotation': 'cheating'},
#    {'annotator': 'annotator02', 'annotation': 'cheating,subversion'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '537472526251982848',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care'},
#    {'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care,harm'}]},
#  {'tweet_id': '751123142295289856',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm,authority'},
#    {'annotator': 'annotator01', 'annotation': 'subversion'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'harm'}]},
#  {'tweet_id': '651265066906570752',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm'},
#    {'annotator': 'annotator01', 'annotation': 'betrayal'},
#    {'annotator': 'annotator02', 'annotation': 'care,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'harm'}]},
#  {'tweet_id': '651891365014466560',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'non-moral'},
#    {'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator03', 'annotation': 'loyalty'}]},
#  {'tweet_id': '751241532577951745',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'fairness'},
#    {'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care,fairness'}]},
#  {'tweet_id': '654112703800283136',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'cheating'},
#    {'annotator': 'annotator01', 'annotation': 'betrayal'},
#    {'annotator': 'annotator02', 'annotation': 'cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'cheating'}]},
#  {'tweet_id': '751289231041900544',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'loyalty'},
#    {'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'care,loyalty,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care,loyalty'}]},
#  {'tweet_id': '593141864972189696',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm'},
#    {'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'harm,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '556802792652693506',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care,purity'},
#    {'annotator': 'annotator01', 'annotation': 'betrayal'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'purity'}]},
#  {'tweet_id': '642968633522683905',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'non-moral'},
#    {'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'non-moral'}]},
#  {'tweet_id': '753237321638486016',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'cheating'},
#    {'annotator': 'annotator01', 'annotation': 'cheating'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'cheating'}]},
#  {'tweet_id': '566241839296942081',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm'},
#    {'annotator': 'annotator01', 'annotation': 'betrayal'},
#    {'annotator': 'annotator02', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator03', 'annotation': 'harm,loyalty'}]},
#  {'tweet_id': '613255754309574656',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'fairness'},
#    {'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '755813182720139264',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator01', 'annotation': 'cheating'},
#    {'annotator': 'annotator02', 'annotation': 'cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '757785943310868480',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'harm'}]},
#  {'tweet_id': '747026547396182016',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care,authority'},
#    {'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care,harm,cheating'}]},
#  {'tweet_id': '634788387443056640',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'non-moral'},
#    {'annotator': 'annotator02', 'annotation': 'cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'non-moral'}]},
#  {'tweet_id': '587986201925263360',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'fairness'},
#    {'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '555828454210674688',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm'},
#    {'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'harm'},
#    {'annotator': 'annotator03', 'annotation': 'harm,fairness,cheating'}]},
#  {'tweet_id': '689262677235859456',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'non-moral'},
#    {'annotator': 'annotator01', 'annotation': 'fairness,betrayal'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness,loyalty'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '700134061403213824',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator01', 'annotation': 'betrayal'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '742834386568159233',
#   'annotations': [{'annotator': 'annotator00',
#     'annotation': 'harm,fairness,cheating'},
#    {'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care,fairness'}]},
#  {'tweet_id': '555686311730753536',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm'},
#    {'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '550385923985530881',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'fairness'},
#    {'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'care'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '718210398210666496',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator01', 'annotation': 'betrayal'},
#    {'annotator': 'annotator02', 'annotation': 'degradation'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating,degradation'}]},
#  {'tweet_id': '593769417558876162',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'fairness'},
#    {'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care,fairness'}]},
#  {'tweet_id': '662773663347974144',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'non-moral'},
#    {'annotator': 'annotator01', 'annotation': 'purity'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '755813295966261248',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator01', 'annotation': 'cheating'},
#    {'annotator': 'annotator02', 'annotation': 'cheating,betrayal,degradation'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '752325281386524672',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'non-moral'},
#    {'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'loyalty'}]},
#  {'tweet_id': '547031491021373440',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care'},
#    {'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'care,authority'}]},
#  {'tweet_id': '677847559415689217',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care,authority'}]},
#  {'tweet_id': '537431692021997568',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'loyalty'},
#    {'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'care,loyalty'}]},
#  {'tweet_id': '612239387246510080',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care,harm'},
#    {'annotator': 'annotator01', 'annotation': 'degradation'},
#    {'annotator': 'annotator02', 'annotation': 'degradation'},
#    {'annotator': 'annotator03', 'annotation': 'harm,purity'}]},
#  {'tweet_id': '755217624565374976',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'authority'},
#    {'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'care,loyalty'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '658283389519273984',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'non-moral'},
#    {'annotator': 'annotator01', 'annotation': 'purity'},
#    {'annotator': 'annotator02', 'annotation': 'fairness'},
#    {'annotator': 'annotator03', 'annotation': 'non-moral'}]},
#  {'tweet_id': '742837381234057216',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care,harm'},
#    {'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care,harm,cheating'}]},
#  {'tweet_id': '755099636730241024',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '751400092020518913',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care'},
#    {'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'care,loyalty,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '537265155865083904',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'fairness'},
#    {'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'fairness'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '657328261710528512',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm'},
#    {'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'harm'}]},
#  {'tweet_id': '753425621091356673',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator01', 'annotation': 'subversion'},
#    {'annotator': 'annotator02', 'annotation': 'cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '594755512425656320',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm'},
#    {'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02',
#     'annotation': 'care,fairness,loyalty,authority,purity'},
#    {'annotator': 'annotator03', 'annotation': 'harm'}]},
#  {'tweet_id': '649768267272163328',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'non-moral'},
#    {'annotator': 'annotator01', 'annotation': 'betrayal'},
#    {'annotator': 'annotator02', 'annotation': 'cheating'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '752775072012644352',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm'},
#    {'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'harm,cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'harm,subversion'}]},
#  {'tweet_id': '558699499728928768',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care'},
#    {'annotator': 'annotator01', 'annotation': 'purity'},
#    {'annotator': 'annotator02', 'annotation': 'loyalty'},
#    {'annotator': 'annotator03', 'annotation': 'purity'}]},
#  {'tweet_id': '673735901328093184',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'care,loyalty,purity'}]},
#  {'tweet_id': '669268803449135111',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care,harm'},
#    {'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'harm'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '592916998545354752',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'harm'},
#    {'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'harm'},
#    {'annotator': 'annotator03', 'annotation': 'harm'}]},
#  {'tweet_id': '624335154555801600',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'care'},
#    {'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care,harm'}]},
#  {'tweet_id': '675750827957596161',
#   'annotations': [{'annotator': 'annotator00',
#     'annotation': 'harm,fairness,cheating'},
#    {'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03',
#     'annotation': 'fairness,cheating,loyalty,authority'}]},
#  {'tweet_id': '665356931226202113',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'fairness'},
#    {'annotator': 'annotator01', 'annotation': 'care,loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care,loyalty'}]},
#  {'tweet_id': '758772824416849920',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'degradation'},
#    {'annotator': 'annotator01', 'annotation': 'degradation'},
#    {'annotator': 'annotator02', 'annotation': 'harm,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'degradation'}]},
#  {'tweet_id': '750875058449616896',
#   'annotations': [{'annotator': 'annotator00', 'annotation': 'authority'},
#    {'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'fairness,loyalty'},
#    {'annotator': 'annotator03', 'annotation': 'authority'}]},
#  {'tweet_id': '751988149178372097',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '555322269581737984',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'care,cheating,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care,loyalty'}]},
#  {'tweet_id': '546509096137289728',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'harm,cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'loyalty,authority'}]},
#  {'tweet_id': '653980302436618240',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'harm,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'non-moral'}]},
#  {'tweet_id': '752180743812493312',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'cheating'}]},
#  {'tweet_id': '660021850630696960',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'care,authority,purity'},
#    {'annotator': 'annotator03', 'annotation': 'authority'}]},
#  {'tweet_id': '612427248944185344',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'care,loyalty,purity'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '537160201929887744',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'fairness,purity'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '667101822511894528',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'cheating'},
#    {'annotator': 'annotator02', 'annotation': 'harm,cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'cheating'}]},
#  {'tweet_id': '597789787672707072',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'purity'},
#    {'annotator': 'annotator03', 'annotation': 'non-moral'},
#    {'annotator': 'annotator17', 'annotation': 'non-moral'}]},
#  {'tweet_id': '751172039168241664',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care,authority'}]},
#  {'tweet_id': '734043340665036800',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'degradation'},
#    {'annotator': 'annotator02', 'annotation': 'harm,cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'cheating,degradation'}]},
#  {'tweet_id': '686324503840858112',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'betrayal'},
#    {'annotator': 'annotator02', 'annotation': 'degradation'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '612463535667462144',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '642687902535782401',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'care'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '546741609321467904',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '544547281635008512',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'non-moral'},
#    {'annotator': 'annotator02', 'annotation': 'care,loyalty'},
#    {'annotator': 'annotator03', 'annotation': 'loyalty'}]},
#  {'tweet_id': '708732668024754176',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'harm'}]},
#  {'tweet_id': '550803013787738112',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '537084797365919744',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness,loyalty'},
#    {'annotator': 'annotator03', 'annotation': 'care,loyalty'}]},
#  {'tweet_id': '630827101407547392',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'care'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '667190910644584448',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'subversion'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating,subversion'}]},
#  {'tweet_id': '637836374633250816',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'care'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '707702427093340160',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'cheating'}]},
#  {'tweet_id': '665433550230044672',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'care,fairness'}]},
#  {'tweet_id': '712393570628603904',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'non-moral'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'authority'}]},
#  {'tweet_id': '624434610831687680',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'degradation'},
#    {'annotator': 'annotator02', 'annotation': 'harm,cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'cheating'}]},
#  {'tweet_id': '540803265290842112',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '638435581215797251',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'non-moral'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'harm,fairness'}]},
#  {'tweet_id': '692948337042001920',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator03', 'annotation': 'care'},
#    {'annotator': 'annotator17', 'annotation': 'non-moral'}]},
#  {'tweet_id': '614563587584081920',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'degradation'},
#    {'annotator': 'annotator02', 'annotation': 'care'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '558309472796278784',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'fairness,authority'}]},
#  {'tweet_id': '751442056724217856',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '594159167046160386',
#   'annotations': [{'annotator': 'annotator01',
#     'annotation': 'fairness,cheating'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness,purity'},
#    {'annotator': 'annotator03', 'annotation': 'fairness,cheating,authority'}]},
#  {'tweet_id': '702235755876392960',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'non-moral'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'care,cheating'}]},
#  {'tweet_id': '544166780667580416',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'loyalty'}]},
#  {'tweet_id': '634048574532161536',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '754865251896537088',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '521022886535245824',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness,loyalty'},
#    {'annotator': 'annotator03', 'annotation': 'fairness,loyalty'}]},
#  {'tweet_id': '759530815617458176',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'care,loyalty'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '669610989466292224',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'loyalty'}]},
#  {'tweet_id': '753691132538781697',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'purity'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '546733385763553280',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '751500064556593152',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'degradation'},
#    {'annotator': 'annotator02', 'annotation': 'degradation'},
#    {'annotator': 'annotator03', 'annotation': 'degradation'}]},
#  {'tweet_id': '755407165247070208',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'subversion'},
#    {'annotator': 'annotator02', 'annotation': 'harm,degradation'},
#    {'annotator': 'annotator03', 'annotation': 'harm'}]},
#  {'tweet_id': '549714084674146306',
#   'annotations': [{'annotator': 'annotator02', 'annotation': 'care'},
#    {'annotator': 'annotator03', 'annotation': 'non-moral'},
#    {'annotator': 'annotator17', 'annotation': 'non-moral'}]},
#  {'tweet_id': '631630754452107265',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'harm'},
#    {'annotator': 'annotator02', 'annotation': 'fairness,cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'harm'}]},
#  {'tweet_id': '750777792309198848',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'fairness'},
#    {'annotator': 'annotator03', 'annotation': 'authority'}]},
#  {'tweet_id': '550835262809702400',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness,loyalty'},
#    {'annotator': 'annotator03', 'annotation': 'non-moral'}]},
#  {'tweet_id': '632433615985512448',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'non-moral'}]},
#  {'tweet_id': '754728117751603201',
#   'annotations': [{'annotator': 'annotator01',
#     'annotation': 'betrayal,authority'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '537112851849445376',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness,loyalty'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '654167700525060097',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'care,cheating'}]},
#  {'tweet_id': '544507643289931777',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'authority'}]},
#  {'tweet_id': '676133826817564672',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'cheating'},
#    {'annotator': 'annotator03', 'annotation': 'harm'}]},
#  {'tweet_id': '632245201466212352',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness,purity'},
#    {'annotator': 'annotator03', 'annotation': 'fairness,loyalty'}]},
#  {'tweet_id': '679250023142531072',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'fairness,cheating,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '602309104384741376',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator03', 'annotation': 'non-moral'},
#    {'annotator': 'annotator17', 'annotation': 'non-moral'}]},
#  {'tweet_id': '615888589524742144',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'care,purity'},
#    {'annotator': 'annotator03', 'annotation': 'care,loyalty'}]},
#  {'tweet_id': '636181271970889729',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness,loyalty'},
#    {'annotator': 'annotator03', 'annotation': 'harm'}]},
#  {'tweet_id': '547423015190134784',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02',
#     'annotation': 'care,fairness,authority,subversion'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating,subversion'}]},
#  {'tweet_id': '595183678805925888',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'harm,cheating,betrayal'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '543920409213931520',
# ...
#  {'tweet_id': '759761158798647297',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'harm,authority'}]},
#  {'tweet_id': '751425363381669888',
#   'annotations': [{'annotator': 'annotator02', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator17', 'annotation': 'non-moral'}]},
#  {'tweet_id': '555309453143457793',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'cheating'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'harm'}]},
#  {'tweet_id': '537479149791637504',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator03', 'annotation': 'loyalty'}]},
#  {'tweet_id': '631442690308222976',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'degradation'},
#    {'annotator': 'annotator02', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator03', 'annotation': 'harm'}]},
#  {'tweet_id': '752304909463195648',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'betrayal'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '751632891508092929',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'non-moral'}]},
#  {'tweet_id': '558137141767962625',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '750739010440617984',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'cheating'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'harm'}]},
#  {'tweet_id': '752926498139443200',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '615888281323077632',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'care,loyalty'}]},
#  {'tweet_id': '751899742800523265',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'non-moral'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'non-moral'}]},
#  {'tweet_id': '755956323821420544',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'harm,cheating'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '546721666739752961',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'care,authority'}]},
#  {'tweet_id': '734245824230793216',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'non-moral'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'care,fairness'}]},
#  {'tweet_id': '546455170578939904',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'cheating'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'care,cheating'}]},
#  {'tweet_id': '584390508895723520',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'loyalty'}]},
#  {'tweet_id': '537475457940082690',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'loyalty'}]},
#  {'tweet_id': '755732308754325505',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating,loyalty'}]},
#  {'tweet_id': '542326282072363008',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'cheating'}]},
#  {'tweet_id': '666027445183713283',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'non-moral'}]},
#  {'tweet_id': '731233964384391169',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'care,fairness'}]},
#  {'tweet_id': '756136943402885123',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'cheating'}]},
#  {'tweet_id': '547060418418446336',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'harm'},
#    {'annotator': 'annotator03', 'annotation': 'cheating'}]},
#  {'tweet_id': '632596600372654080',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '624337275908919298',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'betrayal'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '737353578403221504',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'care,fairness'}]},
#  {'tweet_id': '547371782861520897',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'authority'}]},
#  {'tweet_id': '546469014013493248',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'harm,fairness'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating,authority'}]},
#  {'tweet_id': '576946484328972288',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'authority'}]},
#  {'tweet_id': '627571897677393920',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'non-moral'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'non-moral'}]},
#  {'tweet_id': '543578066313023488',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'betrayal'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '751457023225655297',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'harm,fairness'},
#    {'annotator': 'annotator02', 'annotation': 'harm,subversion'},
#    {'annotator': 'annotator03', 'annotation': 'care,harm,cheating'}]},
#  {'tweet_id': '626510219976159232',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'subversion'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '726157895184859136',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'degradation'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'degradation'}]},
#  {'tweet_id': '654860038880821249',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'non-moral'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '698244793382473729',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'degradation'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'non-moral'}]},
#  {'tweet_id': '565653788380643329',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'purity'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '754723616084856835',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'non-moral'},
#    {'annotator': 'annotator02', 'annotation': 'harm'},
#    {'annotator': 'annotator03', 'annotation': 'betrayal'}]},
#  {'tweet_id': '582169309872402433',
#   'annotations': [{'annotator': 'annotator01',
#     'annotation': 'cheating,authority'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '684259308591165444',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'subversion'},
#    {'annotator': 'annotator03', 'annotation': 'authority'}]},
#  {'tweet_id': '615034207585370113',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'care,harm,cheating,loyalty'}]},
#  {'tweet_id': '637075048248029184',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'fairness,cheating'},
#    {'annotator': 'annotator03', 'annotation': 'care,harm,authority'}]},
#  {'tweet_id': '592788986650873856',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'harm'},
#    {'annotator': 'annotator02', 'annotation': 'harm'},
#    {'annotator': 'annotator03', 'annotation': 'care,harm'}]},
#  {'tweet_id': '572445904327843841',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '642691642496012288',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'cheating'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '546514860318543873',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '670099330515255296',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'care,fairness,loyalty'}]},
#  {'tweet_id': '754745561887027200',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'fairness'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '537332672142786560',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'cheating'},
#    {'annotator': 'annotator02', 'annotation': 'harm'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '678408271464685571',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'harm'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '666608562437824512',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'care'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '674226808632516612',
#   'annotations': [{'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'care'},
#    {'annotator': 'annotator17', 'annotation': 'non-moral'}]},
#  {'tweet_id': '750851678929235968',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'subversion'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '612559896865718272',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '756857026869878784',
#   'annotations': [{'annotator': 'annotator01',
#     'annotation': 'fairness,loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '750681699210506244',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'fairness'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'fairness'}]},
#  {'tweet_id': '701960281988005889',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'degradation'},
#    {'annotator': 'annotator02', 'annotation': 'harm,degradation'},
#    {'annotator': 'annotator03', 'annotation': 'non-moral'}]},
#  {'tweet_id': '637404741916487680',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'betrayal'},
#    {'annotator': 'annotator02', 'annotation': 'degradation'},
#    {'annotator': 'annotator03', 'annotation': 'authority'}]},
#  {'tweet_id': '751634768094072832',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'cheating'},
#    {'annotator': 'annotator02',
#     'annotation': 'authority,subversion,degradation'},
#    {'annotator': 'annotator03', 'annotation': 'care,authority'}]},
#  {'tweet_id': '717387515158798336',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'degradation'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'non-moral'}]},
#  {'tweet_id': '704498060240543744',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'authority'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'authority'}]},
#  {'tweet_id': '717390266395672576',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'betrayal'},
#    {'annotator': 'annotator02', 'annotation': 'harm'},
#    {'annotator': 'annotator03', 'annotation': 'harm'}]},
#  {'tweet_id': '612826623000334336',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'loyalty'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'loyalty'}]},
#  {'tweet_id': '750979372866306048',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'cheating'},
#    {'annotator': 'annotator02', 'annotation': 'cheating'},
#    {'annotator': 'annotator03', 'annotation': 'harm,cheating'}]},
#  {'tweet_id': '555029338769592320',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'care'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'care'}]},
#  {'tweet_id': '632252645223321600',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'non-moral'},
#    {'annotator': 'annotator02', 'annotation': 'care,fairness'},
#    {'annotator': 'annotator03', 'annotation': 'non-moral'}]},
#  {'tweet_id': '704477218148216832',
#   'annotations': [{'annotator': 'annotator01', 'annotation': 'degradation'},
#    {'annotator': 'annotator02', 'annotation': 'non-moral'},
#    {'annotator': 'annotator03', 'annotation': 'non-moral'}]},
#  ...]

# %%
annotations_json['Tweets'][0][0]
# Out:
# {'tweet_id': '521033092132503552',
#  'annotations': [{'annotator': 'annotator00', 'annotation': 'care'},
#   {'annotator': 'annotator01', 'annotation': 'care,purity'},
#   {'annotator': 'annotator02', 'annotation': 'care,purity'},
#   {'annotator': 'annotator03', 'annotation': 'care'}]}

# %%
# get tweets and annotations for each individual annotator
annotators_tweets = {}

for corpus_i in range(len(annotations_json['Corpus'])):
    for tweet in annotations_json['Tweets'][corpus_i]:
        for annotation in tweet['annotations']:
            
            # arrange data format of each tweet 
            new_tweet = {'tweet_id': tweet['tweet_id'], 
                        'annotations': annotation['annotation'], 
                        'corpus': annotations_json['Corpus'][corpus_i]}
            
            # make sure annotator exists in the dictionary
            if annotation['annotator'] not in annotators_tweets:
                annotators_tweets[annotation['annotator']] = []
            
            annotators_tweets[annotation['annotator']].append(new_tweet)

# %%
# visualize annotator01's first 5 tweets with annotations
annotators_tweets['annotator01'][:5]
# Out:
# [{'tweet_id': '521033092132503552',
#   'annotations': 'care,purity',
#   'corpus': 'ALM'},
#  {'tweet_id': '537681598989475841',
#   'annotations': 'subversion',
#   'corpus': 'ALM'},
#  {'tweet_id': '624644420705648640',
#   'annotations': 'fairness',
#   'corpus': 'ALM'},
#  {'tweet_id': '752979765984890884', 'annotations': 'purity', 'corpus': 'ALM'},
#  {'tweet_id': '548029362348765185', 'annotations': 'loyalty', 'corpus': 'ALM'}]

# %%
for annotator in annotators_tweets:
    print(annotator, ', annotated amount:', len(annotators_tweets[annotator]))
# Out:
# annotator00 , annotated amount: 10277
# annotator01 , annotated amount: 11787
# annotator02 , annotated amount: 19556
# annotator03 , annotated amount: 14968
# annotator17 , annotated amount: 3730
# annotator04 , annotated amount: 10482
# annotator12 , annotated amount: 1228
# annotator13 , annotated amount: 5420
# annotator14 , annotated amount: 5416
# annotator15 , annotated amount: 673
# annotator06 , annotated amount: 4089
# annotator05 , annotated amount: 4669
# annotator07 , annotated amount: 4738
# annotator08 , annotated amount: 4805
# annotator16 , annotated amount: 2499
# annotator18 , annotated amount: 2592
# annotator19 , annotated amount: 2478
# annotator20 , annotated amount: 2591
# annotator21 , annotated amount: 2162
# annotator22 , annotated amount: 560
# annotator10 , annotated amount: 4588
# annotator09 , annotated amount: 4591
# annotator11 , annotated amount: 4555
